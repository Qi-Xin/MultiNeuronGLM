# %% [markdown]
# # set up

# %%
import sys
if sys.platform == 'linux':
    sys.path.append("/home/qix/MultiNeuronGLM")
else:
    sys.path.append("D:/Github/MultiNeuronGLM")

# %%
import pandas as pd
import utility_functions as utils
import GLM
from DataLoader import Allen_dataset
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import numpy as np
sns.set_theme()

# %%
# Use self trained K-means results, which have a better likelihood
import pickle
with open('group_id_all_a_c/membership.pickle', 'rb') as handle:
    membership = pickle.load(handle)
with open('group_id_all_a_c/condition_ids.pickle', 'rb') as handle:
    condition_ids = pickle.load(handle)

# %%
# Load LFP data
start_time = 0.0
end_time = 0.50
padding = 0.3
V1 = Allen_dataset(fps=1000,
                   start_time=start_time, 
                   end_time=end_time,
                   padding=padding,
#                    orientation=[0],
                   session_id=757216464,
                   selected_probes=['probeA', 'probeB', 'probeC', 'probeD', 'probeE', 'probeF'],
#                    temporal_frequency=[1,2,4],
                   stimulus_condition_id=[275, 277, 246, 255, 272, 248, 283, 266, 274, 276, 286, 271, 268, 270],
                   stimulus_name='drifting_gratings')

# V1.get_lfp()
# V1.remove_padding(padding)
V1.get_trial_metric_per_unit_per_trial()
# V1.get_trial_metric_per_unit_per_trial(metric_type='spike_times')
V1.get_running(method="mine")
# Out:
# /home/qix/anaconda3/lib/python3.9/site-packages/allensdk/brain_observatory/ecephys/stimulus_table/naming_utilities.py:154: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   movie_rows = table[stim_colname].str.contains(movie_re, na=False)
# /home/qix/anaconda3/lib/python3.9/site-packages/allensdk/brain_observatory/ecephys/ecephys_session.py:1315: UserWarning: Session includes invalid time intervals that could be accessed with the attribute 'invalid_times',Spikes within these intervals are invalid and may need to be excluded from the analysis.
#   warnings.warn("Session includes invalid time intervals that could be accessed with the attribute 'invalid_times',"

# %% [markdown]
# # (failed) Hard threshold

# %% [markdown]
# # (failed) Soft threshold (updated for time-warping)

# %%
# fit
max_iter = 10
num_basis_baseline = 30
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
# use_all = [True, True, False, False, False, True]
use_all = [False, False, False, False, False, False]

probe_list = V1.selected_probes
running_filter = {}
stationary_filter = {}
running_model_list = []
stationary_model_list = []

for i, target_probe in enumerate(probe_list):
    select_trials = V1.running_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], use_all=use_all[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.fit_time_warping_baseline(probe_list[i], verbose=False, max_iter=max_iter)
    running_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    running_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        running_filter[i,j] = filter_list[k]
        k += 1
    
    select_trials = V1.stationary_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], use_all=use_all[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.fit_time_warping_baseline(probe_list[i], verbose=False, max_iter=max_iter)
    stationary_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    stationary_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        stationary_filter[i,j] = filter_list[k]
        k += 1

# %%
# plot results
# use_all are all False
name_list = ['AM', 'PM', 'V1', 'LM', 'AL', 'RL']
fontsize = 15

sns.reset_orig()
# sns.set_theme()
plt.subplots(figsize=(15,10))
for i in range(len(probe_list)):
    for j in range(-1, len(probe_list)):
        ax = plt.subplot(6, 7, i*7+j+1+1, frameon=True)
        filter_index = i,j
        y, ci = running_filter[filter_index]
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, np.exp(y),label='running', color='r')
            plt.fill_between(x, np.exp((y-2*ci)), np.exp((y+2*ci)), color='r', alpha=.3)
        else:
            plt.plot(x, y,label='running', color='r')
            plt.fill_between(x, y-2*ci, y+2*ci, color='r', alpha=.3)
            
        y, ci = stationary_filter[filter_index]
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, np.exp(y),label='stationary', color='b')
            plt.fill_between(x, np.exp((y-2*ci)), np.exp((y+2*ci)), color='b', alpha=.3)
            plt.xticks([0, 250, 500])
            plt.xlim([0, 500])
            
        else:
            plt.plot(x, y,label='stationary', color='b')
            plt.fill_between(x, y-2*ci, y+2*ci, color='b', alpha=.3)
            plt.yticks([0])
            plt.ylim([-0.17, 0.17])
            plt.yticks(color='w')
            plt.xticks([0, 50, 100])
            plt.xlim([0, 100])
            if i==0:
                plt.text(40, 0.2, f'From: {name_list[j]}', fontsize=fontsize)
                
        if j==0:
            plt.text(-210, 0, f'To: {name_list[i]}', fontsize=fontsize)
        if i != 5:
            plt.xticks(color='w')
        plt.grid()
        
        if i==0 and j==2:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(-450, 0, f'To: AM', fontsize=fontsize)
        if i==1 and j==0:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(40, 0.61, f'From: AM', fontsize=fontsize)
        if i==0 and j==-1:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(0, 0.37, f'Inhomo baseline', fontsize=fontsize)

# %%
# Simulation
hard_threshold = 3
tau = 30
model_list = running_model_list
refractory_stength = 0.5

import copy
import numpy.random
nneuron = len(model_list)
# Get three dimension matrix of coupling filters for better computing. 
max_histories = 1
nt = model_list[0].nt
# allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
coupling_mat = np.zeros((max_histories, nneuron, nneuron))
baseline_mat = np.zeros((nt, nneuron))
spikes = np.zeros((nt, nneuron, 1))
probe2num = {}
for iprobe, probe in enumerate(probe_list):
    probe2num[probe] = iprobe

for ineuron in range(nneuron):
    assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
    model = model_list[ineuron]
    for ieffect, effect_type in enumerate(model.effect_type_list):
        
        if effect_type in ['inhomogeneous_baseline']:
            baseline_mat[:, ineuron] = model.filters[ieffect]
        elif effect_type in ['coupling']:
            nhistories = len(model.filters[ieffect])
            probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
            iprobe = probe2num[probe_name]
            if nhistories > max_histories:
                coupling_mat_old = coupling_mat
                coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                coupling_mat[-max_histories:, :, :] = coupling_mat_old
                max_histories = nhistories
            coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

log_firing_rate = baseline_mat[:,:,np.newaxis]
spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

recent_spike_sum = spikes[0, :, 0]

for t in range(1, nt):
    recent_spike_sum *= np.exp(-1000.0/V1.fps/tau)
    nhistories = min(t, max_histories)
    temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
    log_firing_rate[t,:,0] += temp_log_firing_rate - refractory_stength*recent_spike_sum
    spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))
    
    recent_spike_sum += spikes[t, :, 0]

log_firing_rate = log_firing_rate.squeeze()
spikes = spikes.squeeze()

# %%
plt.plot(np.exp(log_firing_rate))
# Out:
# [<matplotlib.lines.Line2D at 0x7fe428b49ca0>,
#  <matplotlib.lines.Line2D at 0x7fe428b87850>,
#  <matplotlib.lines.Line2D at 0x7fe428b87070>,
#  <matplotlib.lines.Line2D at 0x7fe428b49430>,
#  <matplotlib.lines.Line2D at 0x7fe428b49e50>,
#  <matplotlib.lines.Line2D at 0x7fe428b49880>]

# %% [markdown]
# # (failed) Adding population refractory term

# %% [markdown]
# which is the same as a different history filter

# %% [markdown]
# ## Decide history effect tau

# %% [markdown]
# ### probeA

# %%
max_iter = 5
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}

# %%
target_probe = 'probeA'
tau_list = np.logspace(np.log10(1), np.log10(150), 20)

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30
    num_varying_linear = 30

    probe_list = V1.selected_probes
    select_trials = V1.stationary_trial_index
#     select_trials = np.full(V1.ntrial, True)

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)

    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('trial_coef')
    model.add_effect('refractory', target_probe, tau=tau)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append(model.results.params[-1])
    bse_list.append(model.results.bse[-1])
    nll_list.append(model.nll)

# %%
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(r'{target_probe}')
# Out:
# Text(0.5, 1.0, '{target_probe}')

# %% [markdown]
# ### probeB

# %%
target_probe = 'probeB'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30
    num_varying_linear = 30

    probe_list = V1.selected_probes
    select_trials = V1.stationary_trial_index
#     select_trials = np.full(V1.ntrial, True)

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)

    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('trial_coef')
    model.add_effect('refractory', target_probe, tau=tau)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append(model.results.params[-1])
    bse_list.append(model.results.bse[-1])
    nll_list.append(model.nll)

# %%
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,3))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(r'{target_probe}')
# Out:
# Text(0.5, 1.0, '{target_probe}')

# %% [markdown]
# ### probeC

# %%
target_probe = 'probeC'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30
    num_varying_linear = 30

    probe_list = V1.selected_probes
    select_trials = V1.stationary_trial_index
#     select_trials = np.full(V1.ntrial, True)

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)

    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('trial_coef')
    model.add_effect('refractory', target_probe, tau=tau)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append(model.results.params[-1])
    bse_list.append(model.results.bse[-1])
    nll_list.append(model.nll)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [537], in <cell line: 7>()
#      27 model.add_effect('trial_coef')
#      28 model.add_effect('refractory', target_probe, tau=tau)
# ---> 29 model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
#      30 para_list.append(model.results.params[-1])
#      31 bse_list.append(model.results.bse[-1])
#
# File ~/MultiNeuronGLM/GLM.py:486, in PP_GLM.fit_time_warping_baseline(self, target, use_all, max_iter, penalty, tol, verbose)
#     484 self.shifts[:,1] = (self.shifts[:,1] - self.shifts[:,0])*THETA + self.shifts[:,0]
#     485 self.shifts[:,3] = (self.shifts[:,3] - self.shifts[:,2])*THETA + self.shifts[:,2]
# --> 486 X_baseline_warp = apply_warping_to_predictors(self.dataset.time_line, X_baseline_original, self.shifts, self.nt)
#     487 self.effect_list[i_effect] = X_baseline_warp
#     489 if verbose:
#
# File ~/MultiNeuronGLM/GLM.py:593, in apply_warping_to_predictors(time_line, X_baseline_original, shifts, nt)
#     591 for i_col in range(X_baseline_warp.shape[1]):
#     592     to_warp = X_baseline_original[itrial*nt:(itrial+1)*nt, i_col]
# --> 593     warped = linear_time_warping_single(time_line, to_warp, sources1, targets1, verbose=False)
#     594     to_warp = warped
#     595     warped = linear_time_warping_single(time_line, to_warp, sources2, targets2, verbose=False)
#
# File ~/MultiNeuronGLM/GLM.py:618, in linear_time_warping_single(t, f, sources, targets, verbose)
#     615 target_right = targets[i]
#     617 # Linearly stretch the source intervals to the target interverals.
# --> 618 t_target_index = (t >= target_left) & (t < target_right)
#     619 t_target = t[t_target_index]
#     620 if len(t_target) == 0:
#
# KeyboardInterrupt:

# %%
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,3))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(r'{target_probe}')
# Out:
# Text(0.5, 1.0, '{target_probe}')

# %% [markdown]
# ### probeD

# %%
target_probe = 'probeD'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30
    num_varying_linear = 30

    probe_list = V1.selected_probes
    select_trials = V1.stationary_trial_index
#     select_trials = np.full(V1.ntrial, True)

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)

    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('trial_coef')
    model.add_effect('refractory', target_probe, tau=tau)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append(model.results.params[-1])
    bse_list.append(model.results.bse[-1])
    nll_list.append(model.nll)

# %%
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,3))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(r'{target_probe}')
# Out:
# Text(0.5, 1.0, '{target_probe}')

# %% [markdown]
# ### probeE

# %%
target_probe = 'probeE'
tau_list = np.logspace(np.log10(1), np.log10(500), 20)

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30
    num_varying_linear = 30

    probe_list = V1.selected_probes
    select_trials = V1.stationary_trial_index
#     select_trials = np.full(V1.ntrial, True)

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)

    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('trial_coef')
    model.add_effect('refractory', target_probe, tau=tau)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append(model.results.params[-1])
    bse_list.append(model.results.bse[-1])
    nll_list.append(model.nll)

# %%
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,3))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(r'{target_probe}')
# Out:
# Text(0.5, 1.0, '{target_probe}')

# %% [markdown]
# ### probeF

# %%
target_probe = 'probeF'
tau_list = np.logspace(np.log10(1), np.log10(400), 20)

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30
    num_varying_linear = 30

    probe_list = V1.selected_probes
    select_trials = V1.stationary_trial_index
#     select_trials = np.full(V1.ntrial, True)

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)

    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('trial_coef')
    model.add_effect('refractory', target_probe, tau=tau)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append(model.results.params[-1])
    bse_list.append(model.results.bse[-1])
    nll_list.append(model.nll)

# %%
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,3))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(r'{target_probe}')
# Out:
# Text(0.5, 1.0, '{target_probe}')

# %% [markdown]
# ### just some test space

# %%
self_coupling_filter_params = {'peaks_max':70, 'num':10, 'nonlinear':0.3}
_ = GLM.make_pillow_basis(verbose=True, **aaa)

# %%
# Use for test
target_probe = 'probeC'
num_basis_baseline = 30
probe_list = V1.selected_probes
# select_trials = np.full(V1.ntrial, True)
select_trial = V1.stationary_trial_index
# select_trial = V1.running_trial_index

model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)

for j, input_probe in enumerate(probe_list):
    if input_probe=='probeC':
        model.add_effect('coupling', probe_list[j], **self_coupling_filter_params)
    else:
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
# model.add_effect('refractory', target_probe, tau=tau)
model.fit_time_warping_baseline(target_probe, verbose=True, max_iter=max_iter)
# Out:
# After the 0 th iteration of fitting: 32152.815779772915
# After the 0 th iteration of warping: 31653.074411865164
# After the 1 th iteration of fitting: 31397.241049128905
# After the 1 th iteration of warping: 31304.67102524862
# After the 2 th iteration of fitting: 31305.039510833394
# After the 2 th iteration of warping: 31242.165504534194
# After the 3 th iteration of fitting: 31241.976344382878
# After the 3 th iteration of warping: 31156.836667656346
# After the 4 th iteration of fitting: 31158.53655299222
# After the 4 th iteration of warping: 31093.328906097184
# After the 5 th iteration of fitting: 31132.5014317701
# After the 5 th iteration of warping: 31078.396160039065
# After the 6 th iteration of fitting: 31125.583790624267
# After the 6 th iteration of warping: 31074.108847344538
# After the 7 th iteration of fitting: 31123.54288201743
# After the 7 th iteration of warping: 31072.46344259595
# After the 8 th iteration of fitting: 31121.87131980124
# After the 8 th iteration of warping: 31071.40174197657
# After the 9 th iteration of fitting: 31120.099429237744
# After the 9 th iteration of warping: 31069.906256869515

# %%
GLM.plot_GLM_compare(model)

# %%
model.log_lmbd.shape
# Out:
# (500, 129)

# %% [markdown]
# # Poisson GLM

# %% [markdown]
# ## Fit

# %%
num_basis_baseline = 30
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
# use_all = [True, True, False, False, False, True]
use_all = [False, False, False, False, False, False]
tau_list = [30, 30, 20, 25, 22, 10]

probe_list = V1.selected_probes
running_filter = {}
stationary_filter = {}
running_model_list = []
stationary_model_list = []

for i, target_probe in enumerate(probe_list):
    select_trials = V1.running_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], use_all=use_all[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.fit(probe_list[i], verbose=False)
    running_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    running_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        running_filter[i,j] = filter_list[k]
        k += 1
    
    select_trials = V1.stationary_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        if input_probe==target_probe:
            self_coupling_filter_params = {'peaks_max':70, 'num':10, 'nonlinear':0.3}
            model.add_effect('coupling', probe_list[j], **self_coupling_filter_params)
        else:
            model.add_effect('coupling', probe_list[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.fit(probe_list[i], verbose=False)
    stationary_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    stationary_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        stationary_filter[i,j] = filter_list[k]
        k += 1

# %% [markdown]
# ## Plot

# %%
# use_all are all False
name_list = ['AM', 'PM', 'V1', 'LM', 'AL', 'RL']
fontsize = 15

sns.reset_orig()
# sns.set_theme()
plt.subplots(figsize=(15,10))
for i in range(len(probe_list)):
    for j in range(-1, len(probe_list)):
        ax = plt.subplot(6, 7, i*7+j+1+1, frameon=True)
        filter_index = i,j
        y, ci = running_filter[filter_index]
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, np.exp(y),label='running', color='r')
            plt.fill_between(x, np.exp((y-2*ci)), np.exp((y+2*ci)), color='r', alpha=.3)
        else:
            plt.plot(x, y,label='running', color='r')
            plt.fill_between(x, y-2*ci, y+2*ci, color='r', alpha=.3)
            
        y, ci = stationary_filter[filter_index]
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, np.exp(y),label='stationary', color='b')
            plt.fill_between(x, np.exp((y-2*ci)), np.exp((y+2*ci)), color='b', alpha=.3)
            plt.xticks([0, 250, 500])
            plt.xlim([0, 500])
            
        else:
            plt.plot(x, y,label='stationary', color='b')
            plt.fill_between(x, y-2*ci, y+2*ci, color='b', alpha=.3)
            plt.yticks([0])
            plt.ylim([-0.17, 0.17])
            plt.yticks(color='w')
            plt.xticks([0, 50, 100])
            plt.xlim([0, 100])
            if i==0:
                plt.text(40, 0.2, f'From: {name_list[j]}', fontsize=fontsize)
                
        if j==0:
            plt.text(-210, 0, f'To: {name_list[i]}', fontsize=fontsize)
        if i != 5:
            plt.xticks(color='w')
        plt.grid()
        
        if i==0 and j==2:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(-450, 0, f'To: AM', fontsize=fontsize)
        if i==1 and j==0:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(40, 0.61, f'From: AM', fontsize=fontsize)
        if i==0 and j==-1:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(0, 0.37, f'Inhomo baseline', fontsize=fontsize)

# %% [markdown]
# ## Simulation

# %%
tau = 20
refractory_stength = 10
model_list = running_model_list

import copy
import numpy.random
nneuron = len(model_list)
# Get three dimension matrix of coupling filters for better computing. 
max_histories = 1
nt = model_list[0].nt
# allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
coupling_mat = np.zeros((max_histories, nneuron, nneuron))
baseline_mat = np.zeros((nt, nneuron))
spikes = np.zeros((nt, nneuron, 1))
probe2num = {}
for iprobe, probe in enumerate(probe_list):
    probe2num[probe] = iprobe

for ineuron in range(nneuron):
    assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
    model = model_list[ineuron]
    for ieffect, effect_type in enumerate(model.effect_type_list):
        
        if effect_type in ['inhomogeneous_baseline']:
            baseline_mat[:, ineuron] = model.filters[ieffect]
        elif effect_type in ['coupling']:
            nhistories = len(model.filters[ieffect])
            probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
            iprobe = probe2num[probe_name]
            if nhistories > max_histories:
                coupling_mat_old = coupling_mat
                coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                coupling_mat[-max_histories:, :, :] = coupling_mat_old
                max_histories = nhistories
            coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

log_firing_rate = baseline_mat[:,:,np.newaxis]
spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

recent_spike_sum = spikes[0, :, 0]

for t in range(1, nt):
    recent_spike_sum *= np.exp(-1000.0/V1.fps/tau)
    nhistories = min(t, max_histories)
    temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
    log_firing_rate[t,:,0] = temp_log_firing_rate #- refractory_stength*recent_spike_sum
    spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))
    
    recent_spike_sum += spikes[t, :, 0]

log_firing_rate = log_firing_rate.squeeze()
spikes = spikes.squeeze()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 43>()
#      46     temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
#      47     log_firing_rate[t,:,0] = temp_log_firing_rate #- refractory_stength*recent_spike_sum
# ---> 48     spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))
#      50     recent_spike_sum += spikes[t, :, 0]
#      52 log_firing_rate = log_firing_rate.squeeze()
#
# File mtrand.pyx:3592, in numpy.random.mtrand.RandomState.poisson()
#
# File _common.pyx:845, in numpy.random._common.disc()
#
# File _common.pyx:642, in numpy.random._common.discrete_broadcast_d()
#
# File _common.pyx:376, in numpy.random._common.check_array_constraint()
#
# ValueError: lam value too large

# %%
np.random.seed(0)
spikes, log_firing_rate = GLM.simulate(running_model_list)
plt.plot(log_firing_rate)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [27], in <cell line: 2>()
#       1 np.random.seed(0)
# ----> 2 spikes, log_firing_rate = GLM.simulate(running_model_list)
#       3 plt.plot(log_firing_rate)
#
# File ~/MultiNeuronGLM/GLM.py:661, in simulate(model_list, probe_list)
#     658                 max_histories = nhistories
#     659             coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])
# --> 661 spikes, log_firing_rate = simulate_baseline_coupling(baseline_mat, coupling_mat)
#     662 return spikes, log_firing_rate
#
# File ~/MultiNeuronGLM/GLM.py:675, in simulate_baseline_coupling(baseline_mat, coupling_mat)
#     673     temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
#     674     log_firing_rate[t,:,0] += temp_log_firing_rate
# --> 675     spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))
#     677 log_firing_rate = log_firing_rate.squeeze()
#     678 spikes = spikes.squeeze()
#
# File mtrand.pyx:3592, in numpy.random.mtrand.RandomState.poisson()
#
# File _common.pyx:845, in numpy.random._common.disc()
#
# File _common.pyx:642, in numpy.random._common.discrete_broadcast_d()
#
# File _common.pyx:376, in numpy.random._common.check_array_constraint()
#
# ValueError: lam value too large

# %%
model.response.mean()
# Out:
# 0.06886821705426356

# %% [markdown]
# # Binomial GLM time-warping

# %% [markdown]
# ## Fit

# %%
# fit
max_spike_list = [12, 15, 17, 11, 7 ,8]   # Using average number of neurons to define max_spike
max_spike_list = [None]*6
max_iter = 10
num_basis_baseline = 30
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
# use_all = [True, True, False, False, False, True]
use_all = [False, False, False, False, False, False]

probe_list = V1.selected_probes
running_filter = {}
stationary_filter = {}
running_model_list = []
stationary_model_list = []

for i, target_probe in enumerate(probe_list):
    select_trials = V1.running_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], use_all=use_all[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
#     model.fit_time_warping_baseline(probe_list[i], max_iter=max_iter, penalty=0, method='logit', 
#                                     max_spike=max_spike_list[i], verbose=False)
    model.fit(probe_list[i], verbose=False, penalty=0, method='logit', max_spike=max_spike_list[i])
    running_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    running_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        running_filter[i,j] = filter_list[k]
        k += 1
    
    select_trials = V1.stationary_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], use_all=use_all[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
#     model.fit_time_warping_baseline(probe_list[i], max_iter=max_iter, penalty=0, method='logit', 
#                                     max_spike=max_spike_list[i], verbose=False)
    model.fit(probe_list[i], verbose=False, penalty=0, method='logit', max_spike=max_spike_list[i])
    stationary_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    stationary_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        stationary_filter[i,j] = filter_list[k]
        k += 1

# %% [markdown]
# ## Diagnostic

# %%
model = stationary_model_list[2]
link = GLM.get_link('logit')
pred = (link(model.log_lmbd)*model.max_spike)
sns.histplot(pred.flatten('F'))
plt.xlim([-0.1, 2.5])
# Out:
# (-0.1, 2.5)

# %%
n_bin = 100
dd = 0.05
spike_sum = np.zeros(n_bin)
num_sum = np.zeros(n_bin)
for idata, lmbd in enumerate(pred.flatten('F')):
    idx = int(lmbd/dd)
    if idx<n_bin:
        spike_sum[idx] += model.output.flatten('F')[idata]
        num_sum[idx] += 1
xx = np.linspace(0, n_bin*dd, n_bin)
plt.subplots(figsize=(5,4.7))
plt.plot(xx, xx, label='model prediction',color='r')
plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)
plt.legend()
# Out:
# /tmp/ipykernel_36194/1648108287.py:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)

# %%
model = running_model_list[2]
link = GLM.get_link('logit')
pred = (link(model.log_lmbd)*model.max_spike)
sns.histplot(pred.flatten('F'))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
n_bin = 100
dd = 0.03
spike_sum = np.zeros(n_bin)
num_sum = np.zeros(n_bin)
for idata, lmbd in enumerate(pred.flatten('F')):
    idx = int(lmbd/dd)
    if idx<n_bin:
        spike_sum[idx] += model.output.flatten('F')[idata]
        num_sum[idx] += 1
xx = np.linspace(0, n_bin*dd, n_bin)
plt.subplots(figsize=(5,4.7))
plt.plot(xx, xx, label='model prediction',color='r')
plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)
plt.legend()
# Out:
# /tmp/ipykernel_36194/1538484403.py:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)

# %%
(pred>=3).sum()

# %% [markdown]
# ## Plot

# %%
# plot results
# use_all are all False
logit = lambda xb: 1/(1+np.exp(-xb))
link = logit
name_list = ['AM', 'PM', 'V1', 'LM', 'AL', 'RL']
fontsize = 15

sns.reset_orig()
# sns.set_theme()
plt.subplots(figsize=(15,10))
for i in range(len(probe_list)):
    for j in range(-1, len(probe_list)):
        ax = plt.subplot(6, 7, i*7+j+1+1, frameon=True)
        filter_index = i,j
        y, ci = running_filter[filter_index]
        spikes_max = running_model_list[i].max_spike
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, spikes_max*link(y),label='running', color='r')
            plt.fill_between(x, spikes_max*link((y-2*ci)), spikes_max*link((y+2*ci)), color='r', alpha=.3)
        else:
            plt.plot(x, y,label='running', color='r')
            plt.fill_between(x, y-2*ci, y+2*ci, color='r', alpha=.3)
            
        y, ci = stationary_filter[filter_index]
        spikes_max = stationary_model_list[i].max_spike
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, spikes_max*link(y),label='stationary', color='b')
            plt.fill_between(x, spikes_max*link((y-2*ci)), spikes_max*link((y+2*ci)), color='b', alpha=.3)
            plt.xticks([0, 250, 500])
            plt.xlim([0, 500])
            
        else:
            plt.plot(x, y,label='stationary', color='b')
            plt.fill_between(x, y-2*ci, y+2*ci, color='b', alpha=.3)
            plt.yticks([0])
            plt.ylim([-0.17, 0.17])
            plt.yticks(color='w')
            plt.xticks([0, 50, 100])
            plt.xlim([0, 100])
            if i==0:
                plt.text(40, 0.2, f'From: {name_list[j]}', fontsize=fontsize)
                
        if j==0:
            plt.text(-210, 0, f'To: {name_list[i]}', fontsize=fontsize)
        if i != 5:
            plt.xticks(color='w')
        plt.grid()
        
        if i==0 and j==2:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(-450, 0, f'To: AM', fontsize=fontsize)
        if i==1 and j==0:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(40, 0.61, f'From: AM', fontsize=fontsize)
        if i==0 and j==-1:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(0, 0.37, f'Inhomo baseline', fontsize=fontsize)

# %% [markdown]
# ## Simulate running_model_list

# %%
model_list = running_model_list

import copy
import numpy.random
nneuron = len(model_list)
# Get three dimension matrix of coupling filters for better computing. 
max_histories = 1
nt = model_list[0].nt
# allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
coupling_mat = np.zeros((max_histories, nneuron, nneuron))
baseline_mat = np.zeros((nt, nneuron))
spikes = np.zeros((nt, nneuron, 1)).astype(int)
probe2num = {}
for iprobe, probe in enumerate(probe_list):
    probe2num[probe] = iprobe
    
spikes_max_list = np.zeros(6)
for iprobe, probe in enumerate(probe_list):
    spikes_max_list[iprobe] = model_list[iprobe].max_spike

for ineuron in range(nneuron):
    assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
    model = model_list[ineuron]
    for ieffect, effect_type in enumerate(model.effect_type_list):
        
        if effect_type in ['inhomogeneous_baseline']:
            baseline_mat[:, ineuron] = model.filters[ieffect]
        elif effect_type in ['coupling']:
            nhistories = len(model.filters[ieffect])
            probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
            iprobe = probe2num[probe_name]
            if nhistories > max_histories:
                coupling_mat_old = coupling_mat
                coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                coupling_mat[-max_histories:, :, :] = coupling_mat_old
                max_histories = nhistories
            coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

log_firing_rate = baseline_mat[:,:,np.newaxis]
spikes[0,:,0] = np.random.binomial(spikes_max_list.astype(int), logit(log_firing_rate[0,:,0]))

recent_spike_sum = spikes[0, :, 0]

for t in range(1, nt):
#     recent_spike_sum *= np.exp(-1000.0/V1.fps/tau)
    nhistories = min(t, max_histories)
    temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
    log_firing_rate[t,:,0] += temp_log_firing_rate #- refractory_stength*recent_spike_sum
    spikes[t,:,0] = np.random.binomial(spikes_max_list.astype(int), logit(log_firing_rate[t,:,0]))
    
#     recent_spike_sum += spikes[t, :, 0]

log_firing_rate = log_firing_rate.squeeze()
firing_rate = logit(log_firing_rate)*spikes_max_list[np.newaxis,:]
spikes = spikes.squeeze()

# %% [markdown]
# ### Single trial plot

# %%
try:
    to_plot_end = np.where(firing_rate.squeeze().mean(axis=1)>10)[0][0]
    plt.plot(firing_rate[:to_plot_end,:])
except IndexError:
    plt.plot(firing_rate)
plt.legend(['AM','PM','V1','LM','AL','RL'])
plt.title("Firing rate of a single trial (running)")
# Out:
# Text(0.5, 1.0, 'Firing rate of a single trial (running)')

# %% [markdown]
# ### PSTH

# %%
MAX_FIRING_RATE = 2
# MAX_FIRING_RATE = np.log(np.array([0.70520469, 0.29707425, 1.10850376, 0.56863778, 1.64858215, -0.24620009])+0.3)
model_list = running_model_list
spikes_rcd = np.zeros((model_list[0].nt, 6, model_list[0].ntrial))
log_firing_rate_rcd = np.zeros((model_list[0].nt, 6, model_list[0].ntrial))
explosion_trial = 0

import copy
import numpy.random

for itrial in range(model_list[0].ntrial):
    while True:
        nneuron = len(model_list)
        # Get three dimension matrix of coupling filters for better computing. 
        max_histories = 1
        nt = model_list[0].nt
        # allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
        allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
        coupling_mat = np.zeros((max_histories, nneuron, nneuron))
        baseline_mat = np.zeros((nt, nneuron))
        spikes = np.zeros((nt, nneuron, 1))
        probe2num = {}
        for iprobe, probe in enumerate(probe_list):
            probe2num[probe] = iprobe

        for ineuron in range(nneuron):
            assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
            model = model_list[ineuron]
            for ieffect, effect_type in enumerate(model.effect_type_list):

                if effect_type in ['inhomogeneous_baseline', ]:
                    baseline_mat[:, ineuron] = model.filters[ieffect]
                    baseline_mat[:, ineuron] = GLM.apply_warping_to_predictors(V1.time_line, 
                                                                               baseline_mat[:, ineuron][:,None], 
                                                                               model_list[0].shifts[itrial,:][None,:], 
                                                                               model_list[0].nt).squeeze()
                elif effect_type in ['coupling']:
                    nhistories = len(model.filters[ieffect])
                    probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
                    iprobe = probe2num[probe_name]
                    if nhistories > max_histories:
                        coupling_mat_old = coupling_mat
                        coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                        coupling_mat[-max_histories:, :, :] = coupling_mat_old
                        max_histories = nhistories
                    coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

        log_firing_rate = baseline_mat[:,:,np.newaxis]
        spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

        recent_spike_sum = spikes[0, :, 0]

        for t in range(1, nt):
            nhistories = min(t, max_histories)
            temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
            log_firing_rate[t,:,0] += temp_log_firing_rate
            log_firing_rate[t,:,0] = np.minimum(log_firing_rate[t,:,0], MAX_FIRING_RATE)
            spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))

        log_firing_rate = log_firing_rate.squeeze()
        spikes = spikes.squeeze()
        
        if np.any(log_firing_rate==MAX_FIRING_RATE):
            explosion_trial += 1
            pass
        else:
            spikes_rcd[:,:,itrial] = spikes
            log_firing_rate_rcd[:,:,itrial] = log_firing_rate
            break

# %%
explosion_trial/(explosion_trial+model_list[0].ntrial)
# Out:
# 0.0

# %%
for iprobe, probe in enumerate(probe_list):
    plt.plot(link(log_firing_rate_rcd)[:,iprobe,].mean(axis=1), label=utils.PROBE_CORRESPONDING[probe])
plt.legend()
plt.title("PSTH of simulation (running)")
# Out:
# Text(0.5, 1.0, 'PSTH of simulation (running)')

# %% [markdown]
# ## Simulate stationary_model_list

# %%
model_list = stationary_model_list

import copy
import numpy.random
nneuron = len(model_list)
# Get three dimension matrix of coupling filters for better computing. 
max_histories = 1
nt = model_list[0].nt
# allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
coupling_mat = np.zeros((max_histories, nneuron, nneuron))
baseline_mat = np.zeros((nt, nneuron))
spikes = np.zeros((nt, nneuron, 1)).astype(int)
probe2num = {}
for iprobe, probe in enumerate(probe_list):
    probe2num[probe] = iprobe
    
spikes_max_list = np.zeros(6)
for iprobe, probe in enumerate(probe_list):
    spikes_max_list[iprobe] = model_list[iprobe].max_spike

for ineuron in range(nneuron):
    assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
    model = model_list[ineuron]
    for ieffect, effect_type in enumerate(model.effect_type_list):
        
        if effect_type in ['inhomogeneous_baseline']:
            baseline_mat[:, ineuron] = model.filters[ieffect]
        elif effect_type in ['coupling']:
            nhistories = len(model.filters[ieffect])
            probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
            iprobe = probe2num[probe_name]
            if nhistories > max_histories:
                coupling_mat_old = coupling_mat
                coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                coupling_mat[-max_histories:, :, :] = coupling_mat_old
                max_histories = nhistories
            coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

log_firing_rate = baseline_mat[:,:,np.newaxis]
spikes[0,:,0] = np.random.binomial(spikes_max_list.astype(int), logit(log_firing_rate[0,:,0]))

recent_spike_sum = spikes[0, :, 0]

for t in range(1, nt):
#     recent_spike_sum *= np.exp(-1000.0/V1.fps/tau)
    nhistories = min(t, max_histories)
    temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
    log_firing_rate[t,:,0] += temp_log_firing_rate #- refractory_stength*recent_spike_sum
    spikes[t,:,0] = np.random.binomial(spikes_max_list.astype(int), logit(log_firing_rate[t,:,0]))
    
#     recent_spike_sum += spikes[t, :, 0]

log_firing_rate = log_firing_rate.squeeze()
firing_rate = logit(log_firing_rate)*spikes_max_list[np.newaxis,:]
spikes = spikes.squeeze()

# %% [markdown]
# ### Single trial plot

# %%
try:
    to_plot_end = np.where(firing_rate.squeeze().mean(axis=1)>10)[0][0]
    plt.plot(firing_rate[:to_plot_end,:])
except IndexError:
    plt.plot(firing_rate)
plt.legend(['AM','PM','V1','LM','AL','RL'])
plt.title("Firing rate of a single trial (stationary)")
# Out:
# Text(0.5, 1.0, 'Firing rate of a single trial (stationary)')

# %% [markdown]
# ### PSTH

# %%
MAX_FIRING_RATE = 2
# MAX_FIRING_RATE = np.log(np.array([0.70520469, 0.29707425, 1.10850376, 0.56863778, 1.64858215, -0.24620009])+0.3)
model_list = stationary_model_list
spikes_rcd = np.zeros((model_list[0].nt, 6, model_list[0].ntrial))
log_firing_rate_rcd = np.zeros((model_list[0].nt, 6, model_list[0].ntrial))
explosion_trial = 0

import copy
import numpy.random

for itrial in range(model_list[0].ntrial):
    while True:
        nneuron = len(model_list)
        # Get three dimension matrix of coupling filters for better computing. 
        max_histories = 1
        nt = model_list[0].nt
        # allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
        allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
        coupling_mat = np.zeros((max_histories, nneuron, nneuron))
        baseline_mat = np.zeros((nt, nneuron))
        spikes = np.zeros((nt, nneuron, 1))
        probe2num = {}
        for iprobe, probe in enumerate(probe_list):
            probe2num[probe] = iprobe

        for ineuron in range(nneuron):
            assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
            model = model_list[ineuron]
            for ieffect, effect_type in enumerate(model.effect_type_list):

                if effect_type in ['inhomogeneous_baseline', ]:
                    baseline_mat[:, ineuron] = model.filters[ieffect]
                    baseline_mat[:, ineuron] = GLM.apply_warping_to_predictors(V1.time_line, 
                                                                               baseline_mat[:, ineuron][:,None], 
                                                                               model_list[0].shifts[itrial,:][None,:], 
                                                                               model_list[0].nt).squeeze()
                elif effect_type in ['coupling']:
                    nhistories = len(model.filters[ieffect])
                    probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
                    iprobe = probe2num[probe_name]
                    if nhistories > max_histories:
                        coupling_mat_old = coupling_mat
                        coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                        coupling_mat[-max_histories:, :, :] = coupling_mat_old
                        max_histories = nhistories
                    coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

        log_firing_rate = baseline_mat[:,:,np.newaxis]
        spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

        recent_spike_sum = spikes[0, :, 0]

        for t in range(1, nt):
            nhistories = min(t, max_histories)
            temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
            log_firing_rate[t,:,0] += temp_log_firing_rate
            log_firing_rate[t,:,0] = np.minimum(log_firing_rate[t,:,0], MAX_FIRING_RATE)
            spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))

        log_firing_rate = log_firing_rate.squeeze()
        spikes = spikes.squeeze()
        
        if np.any(log_firing_rate==MAX_FIRING_RATE):
            explosion_trial += 1
            pass
        else:
            spikes_rcd[:,:,itrial] = spikes
            log_firing_rate_rcd[:,:,itrial] = log_firing_rate
            break

# %%
explosion_trial/(explosion_trial+model_list[0].ntrial)
# Out:
# 0.8700906344410876

# %%
for iprobe, probe in enumerate(probe_list):
    plt.plot(np.exp(log_firing_rate_rcd)[:,iprobe,].mean(axis=1), label=utils.PROBE_CORRESPONDING[probe])
plt.legend()
plt.title("PSTH of simulation (stationary)")
# Out:
# Text(0.5, 1.0, 'PSTH of simulation (stationary)')

# %%
# plot results
# use_all are all False
logit = lambda xb: 1/(1+np.exp(-xb))
link = logit
name_list = ['AM', 'PM', 'V1', 'LM', 'AL', 'RL']
fontsize = 15

sns.reset_orig()
# sns.set_theme()
plt.subplots(figsize=(15,10))
for i in range(len(probe_list)):
    for j in range(-1, len(probe_list)):
        ax = plt.subplot(6, 7, i*7+j+1+1, frameon=True)
        filter_index = i,j
        y, ci = running_filter[filter_index]
        spikes_max = running_model_list[i].max_spike
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, spikes_max*link(y),label='running', color='r')
            plt.fill_between(x, spikes_max*link((y-2*ci)), spikes_max*link((y+2*ci)), color='r', alpha=.3)
        else:
            plt.plot(x, y,label='running', color='r')
            plt.fill_between(x, y-2*ci, y+2*ci, color='r', alpha=.3)
            
        y, ci = stationary_filter[filter_index]
        spikes_max = stationary_model_list[i].max_spike
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, spikes_max*link(y),label='stationary', color='b')
            plt.fill_between(x, spikes_max*link((y-2*ci)), spikes_max*link((y+2*ci)), color='b', alpha=.3)
            plt.xticks([0, 250, 500])
            plt.xlim([0, 500])
            
        else:
            plt.plot(x, y,label='stationary', color='b')
            plt.fill_between(x, y-2*ci, y+2*ci, color='b', alpha=.3)
            plt.yticks([0])
            plt.ylim([-0.17, 0.17])
            plt.yticks(color='w')
            plt.xticks([0, 50, 100])
            plt.xlim([0, 100])
            if i==0:
                plt.text(40, 0.2, f'From: {name_list[j]}', fontsize=fontsize)
                
        if j==0:
            plt.text(-210, 0, f'To: {name_list[i]}', fontsize=fontsize)
        if i != 5:
            plt.xticks(color='w')
        plt.grid()
        
        if i==0 and j==2:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(-450, 0, f'To: AM', fontsize=fontsize)
        if i==1 and j==0:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(40, 0.61, f'From: AM', fontsize=fontsize)
        if i==0 and j==-1:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(0, 0.37, f'Inhomo baseline', fontsize=fontsize)

# %%
def logit_six(xb, spikes_max_list):
    return logit(xb)*spikes_max_list

# %%
logit(log_firing_rate[0,:,0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 logit(log_firing_rate[0,:,0])
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %% [markdown]
# # Poisson GLM Time-warping (simultaneously)

# %% [markdown]
# ## Fit

# %%
self_effect = True
max_iter = 10
num_basis_baseline = 40
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
self_coupling_filter_params = {'peaks_max':70, 'num':10, 'nonlinear':0.3}

# use_all = [True, True, False, False, False, True]
use_all = [False, False, False, False, False, False]
tau_list = [30, 30, 20, 25, 22, 10]

probe_list = V1.selected_probes
running_filter = {}
stationary_filter = {}
running_model_list = []
stationary_model_list = []

for i, target_probe in enumerate(probe_list):
    select_trials = V1.running_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        if input_probe=='probeC' and target_probe=='probeC':
            model.add_effect('coupling', probe_list[j], **self_coupling_filter_params)
        else:
            model.add_effect('coupling', probe_list[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.fit_time_warping_baseline(probe_list[i], verbose=False, max_iter=max_iter)
    running_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    running_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        running_filter[i,j] = filter_list[k]
        k += 1
    
    select_trials = V1.stationary_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        if input_probe=='probeC' and target_probe=='probeC':
            model.add_effect('coupling', probe_list[j], **self_coupling_filter_params)
        else:
            model.add_effect('coupling', probe_list[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.fit_time_warping_baseline(probe_list[i], verbose=False, max_iter=max_iter)
    stationary_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    stationary_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        stationary_filter[i,j] = filter_list[k]
        k += 1

# %% [markdown]
# ## Diagnostic

# %%
model = stationary_model_list[2]
sns.histplot(np.exp(model.log_lmbd).flatten('F'))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
n_bin = 100
dd = 0.05
spike_sum = np.zeros(n_bin)
num_sum = np.zeros(n_bin)
for idata, lmbd in enumerate(np.exp(model.log_lmbd).flatten('F')):
    idx = int(lmbd/dd)
    if idx<n_bin:
        spike_sum[idx] += model.output.flatten('F')[idata]
        num_sum[idx] += 1
xx = np.linspace(0, n_bin*dd, n_bin)
plt.subplots(figsize=(5,4.7))
plt.plot(xx, xx, label='model prediction',color='r')
plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)
plt.legend()
# Out:
# /tmp/ipykernel_36194/3381260263.py:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)

# %%
(np.exp(model.log_lmbd)>=3).sum()
# Out:
# 148

# %% [markdown]
# ## Plot

# %%
# use_all are all False
name_list = ['AM', 'PM', 'V1', 'LM', 'AL', 'RL']
fontsize = 15

sns.reset_orig()
# sns.set_theme()
plt.subplots(figsize=(15,10))
for i in range(len(probe_list)):
    for j in range(-1, len(probe_list)):
        if i==j and self_effect==False:
            continue
        ax = plt.subplot(6, 7, i*7+j+1+1, frameon=True)
        filter_index = i,j
        y, ci = running_filter[filter_index]
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, np.exp(y),label='running', color='r')
            plt.fill_between(x, np.exp((y-2*ci)), np.exp((y+2*ci)), color='r', alpha=.3)
        else:
            plt.plot(x, y,label='running', color='r')
            plt.fill_between(x, y-2*ci, y+2*ci, color='r', alpha=.3)
            
        y, ci = stationary_filter[filter_index]
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, np.exp(y),label='stationary', color='b')
            plt.fill_between(x, np.exp((y-2*ci)), np.exp((y+2*ci)), color='b', alpha=.3)
            plt.xticks([0, 250, 500])
            plt.xlim([0, 500])
            
        else:
            plt.plot(x, y,label='stationary', color='b')
            plt.fill_between(x, y-2*ci, y+2*ci, color='b', alpha=.3)
            plt.yticks([0])
            plt.ylim([-0.17, 0.17])
            plt.yticks(color='w')
            plt.xticks([0, 50, 100])
            plt.xlim([0, 100])
            if i==0:
                plt.text(40, 0.2, f'From: {name_list[j]}', fontsize=fontsize)
                
        if j==0:
            plt.text(-210, 0, f'To: {name_list[i]}', fontsize=fontsize)
        if i != 5:
            plt.xticks(color='w')
        plt.grid()
        
        if i==0 and j==2:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(-450, 0, f'To: AM', fontsize=fontsize)
        if i==1 and j==0:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(40, 0.61, f'From: AM', fontsize=fontsize)
        if i==0 and j==-1:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(0, 0.37, f'Inhomo baseline', fontsize=fontsize)

# %% [markdown]
# ## Simulate running_model_list

# %%
MAX_FIRING_RATE = 2
# MAX_FIRING_RATE = np.log(np.array([0.70520469, 0.29707425, 1.10850376, 0.56863778, 1.64858215, -0.24620009])+0.3)
model_list = running_model_list
itrial = 0

import copy
import numpy.random
nneuron = len(model_list)
# Get three dimension matrix of coupling filters for better computing. 
max_histories = 1
nt = model_list[0].nt
# allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
coupling_mat = np.zeros((max_histories, nneuron, nneuron))
baseline_mat = np.zeros((nt, nneuron))
spikes = np.zeros((nt, nneuron, 1))
probe2num = {}
for iprobe, probe in enumerate(probe_list):
    probe2num[probe] = iprobe

for ineuron in range(nneuron):
    assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
    model = model_list[ineuron]
    for ieffect, effect_type in enumerate(model.effect_type_list):
        
        if effect_type in ['inhomogeneous_baseline', ]:
            baseline_mat[:, ineuron] = model.filters[ieffect]
#             baseline_mat[:, ineuron] = GLM.apply_warping_to_predictors(V1.time_line, 
#                                                                        baseline_mat[:, ineuron][:,None], 
#                                                                        model_list[0].shifts[itrial,:][None,:], 
#                                                                        model_list[0].nt).squeeze()
        elif effect_type in ['coupling']:
            nhistories = len(model.filters[ieffect])
            probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
            iprobe = probe2num[probe_name]
            if nhistories > max_histories:
                coupling_mat_old = coupling_mat
                coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                coupling_mat[-max_histories:, :, :] = coupling_mat_old
                max_histories = nhistories
            coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

log_firing_rate = baseline_mat[:,:,np.newaxis]
spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

recent_spike_sum = spikes[0, :, 0]

for t in range(1, nt):
    nhistories = min(t, max_histories)
    temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
    log_firing_rate[t,:,0] += temp_log_firing_rate
    log_firing_rate[t,:,0] = np.minimum(log_firing_rate[t,:,0], MAX_FIRING_RATE)
    spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))

log_firing_rate = log_firing_rate.squeeze()
spikes = spikes.squeeze()

# %% [markdown]
# ### Single trial plot

# %%
try:
    to_plot_end = np.where(log_firing_rate.squeeze().mean(axis=1)>10)[0][0]
    plt.plot(np.exp(log_firing_rate.squeeze()[:to_plot_end,:]))
except IndexError:
    plt.plot(np.exp(log_firing_rate.squeeze()[:,:]))
plt.legend(['AM','PM','V1','LM','AL','RL'])
plt.title("Firing rate of a single trial (running)")
# Out:
# Text(0.5, 1.0, 'Firing rate of a single trial (running)')

# %% [markdown]
# ### PSTH

# %%
MAX_FIRING_RATE = 2
# MAX_FIRING_RATE = np.log(np.array([0.70520469, 0.29707425, 1.10850376, 0.56863778, 1.64858215, -0.24620009])+0.3)
model_list = running_model_list
spikes_rcd = np.zeros((model_list[0].nt, 6, model_list[0].ntrial))
log_firing_rate_rcd = np.zeros((model_list[0].nt, 6, model_list[0].ntrial))
explosion_trial = 0

import copy
import numpy.random

for itrial in range(model_list[0].ntrial):
    while True:
        nneuron = len(model_list)
        # Get three dimension matrix of coupling filters for better computing. 
        max_histories = 1
        nt = model_list[0].nt
        # allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
        allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
        coupling_mat = np.zeros((max_histories, nneuron, nneuron))
        baseline_mat = np.zeros((nt, nneuron))
        spikes = np.zeros((nt, nneuron, 1))
        probe2num = {}
        for iprobe, probe in enumerate(probe_list):
            probe2num[probe] = iprobe

        for ineuron in range(nneuron):
            assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
            model = model_list[ineuron]
            for ieffect, effect_type in enumerate(model.effect_type_list):

                if effect_type in ['inhomogeneous_baseline', ]:
                    baseline_mat[:, ineuron] = model.filters[ieffect]
                    baseline_mat[:, ineuron] = GLM.apply_warping_to_predictors(V1.time_line, 
                                                                               baseline_mat[:, ineuron][:,None], 
                                                                               model_list[0].shifts[itrial,:][None,:], 
                                                                               model_list[0].nt).squeeze()
                elif effect_type in ['coupling']:
                    nhistories = len(model.filters[ieffect])
                    probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
                    iprobe = probe2num[probe_name]
                    if nhistories > max_histories:
                        coupling_mat_old = coupling_mat
                        coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                        coupling_mat[-max_histories:, :, :] = coupling_mat_old
                        max_histories = nhistories
                    coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

        log_firing_rate = baseline_mat[:,:,np.newaxis]
        spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

        recent_spike_sum = spikes[0, :, 0]

        for t in range(1, nt):
            nhistories = min(t, max_histories)
            temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
            log_firing_rate[t,:,0] += temp_log_firing_rate
            log_firing_rate[t,:,0] = np.minimum(log_firing_rate[t,:,0], MAX_FIRING_RATE)
            spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))

        log_firing_rate = log_firing_rate.squeeze()
        spikes = spikes.squeeze()
        
        if np.any(log_firing_rate==MAX_FIRING_RATE):
            explosion_trial += 1
            pass
        else:
            spikes_rcd[:,:,itrial] = spikes
            log_firing_rate_rcd[:,:,itrial] = log_firing_rate
            break

# %%
explosion_trial/(explosion_trial+model_list[0].ntrial)
# Out:
# 0.41304347826086957

# %%
for iprobe, probe in enumerate(probe_list):
    plt.plot(np.exp(log_firing_rate_rcd)[:,iprobe,].mean(axis=1), label=utils.PROBE_CORRESPONDING[probe])
plt.legend()
plt.title("PSTH of simulation (running)")
# Out:
# Text(0.5, 1.0, 'PSTH of simulation (running)')

# %% [markdown]
# ## Simulate stationary_model_list

# %%
MAX_FIRING_RATE = 2
# MAX_FIRING_RATE = np.array([0.70520469, 0.29707425, 1.10850376, 0.56863778, 1.64858215, -0.24620009])+0.1
model_list = stationary_model_list

import copy
import numpy.random
nneuron = len(model_list)
# Get three dimension matrix of coupling filters for better computing. 
max_histories = 1
nt = model_list[0].nt
# allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
coupling_mat = np.zeros((max_histories, nneuron, nneuron))
baseline_mat = np.zeros((nt, nneuron))
spikes = np.zeros((nt, nneuron, 1))
probe2num = {}
for iprobe, probe in enumerate(probe_list):
    probe2num[probe] = iprobe

for ineuron in range(nneuron):
    assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
    model = model_list[ineuron]
    for ieffect, effect_type in enumerate(model.effect_type_list):
        
        if effect_type in ['inhomogeneous_baseline', ]:
            baseline_mat[:, ineuron] = model.filters[ieffect]
#             baseline_mat[:, ineuron] = GLM.apply_warping_to_predictors(V1.time_line, 
#                                                                        baseline_mat[:, ineuron][:,None], 
#                                                                        model_list[0].shifts[itrial,:][None,:], 
#                                                                        model_list[0].nt).squeeze()
        elif effect_type in ['coupling']:
            nhistories = len(model.filters[ieffect])
            probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
            iprobe = probe2num[probe_name]
            if nhistories > max_histories:
                coupling_mat_old = coupling_mat
                coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                coupling_mat[-max_histories:, :, :] = coupling_mat_old
                max_histories = nhistories
            coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

log_firing_rate = baseline_mat[:,:,np.newaxis]
spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

recent_spike_sum = spikes[0, :, 0]

for t in range(1, nt):
    nhistories = min(t, max_histories)
    temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
    log_firing_rate[t,:,0] += temp_log_firing_rate
    log_firing_rate[t,:,0] = np.minimum(log_firing_rate[t,:,0], MAX_FIRING_RATE)
    spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))

log_firing_rate = log_firing_rate.squeeze()
spikes = spikes.squeeze()

# %% [markdown]
# ### Single trial plot

# %%
try:
    to_plot_end = np.where(log_firing_rate.squeeze().mean(axis=1)>10)[0][0]
    plt.plot(np.exp(log_firing_rate.squeeze()[:to_plot_end,:]))
except IndexError:
    plt.plot(np.exp(log_firing_rate.squeeze()[:,:]))

plt.legend(['AM','PM','V1','LM','AL','RL'])
plt.title("Firing rate of a single trial (stationary)")
# Out:
# Text(0.5, 1.0, 'Firing rate of a single trial (stationary)')

# %% [markdown]
# ### PSTH

# %%
MAX_FIRING_RATE = 2
# MAX_FIRING_RATE = np.log(np.array([0.70520469, 0.29707425, 1.10850376, 0.56863778, 1.64858215, -0.24620009])+0.3)
model_list = stationary_model_list
spikes_rcd = np.zeros((model_list[0].nt, 6, model_list[0].ntrial))
log_firing_rate_rcd = np.zeros((model_list[0].nt, 6, model_list[0].ntrial))
explosion_trial = 0

import copy
import numpy.random

for itrial in range(model_list[0].ntrial):
    while True:
        nneuron = len(model_list)
        # Get three dimension matrix of coupling filters for better computing. 
        max_histories = 1
        nt = model_list[0].nt
        # allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
        allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef']
        coupling_mat = np.zeros((max_histories, nneuron, nneuron))
        baseline_mat = np.zeros((nt, nneuron))
        spikes = np.zeros((nt, nneuron, 1))
        probe2num = {}
        for iprobe, probe in enumerate(probe_list):
            probe2num[probe] = iprobe

        for ineuron in range(nneuron):
            assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), "Only support inhomogeneous_baseline and coupling effects now!"
            model = model_list[ineuron]
            for ieffect, effect_type in enumerate(model.effect_type_list):

                if effect_type in ['inhomogeneous_baseline', ]:
                    baseline_mat[:, ineuron] = model.filters[ieffect]
                    baseline_mat[:, ineuron] = GLM.apply_warping_to_predictors(V1.time_line, 
                                                                               baseline_mat[:, ineuron][:,None], 
                                                                               model_list[0].shifts[itrial,:][None,:], 
                                                                               model_list[0].nt).squeeze()
                elif effect_type in ['coupling']:
                    nhistories = len(model.filters[ieffect])
                    probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
                    iprobe = probe2num[probe_name]
                    if nhistories > max_histories:
                        coupling_mat_old = coupling_mat
                        coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                        coupling_mat[-max_histories:, :, :] = coupling_mat_old
                        max_histories = nhistories
                    coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])

        log_firing_rate = baseline_mat[:,:,np.newaxis]
        spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

        recent_spike_sum = spikes[0, :, 0]

        for t in range(1, nt):
            nhistories = min(t, max_histories)
            temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
            log_firing_rate[t,:,0] += temp_log_firing_rate
            log_firing_rate[t,:,0] = np.minimum(log_firing_rate[t,:,0], MAX_FIRING_RATE)
            spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))

        log_firing_rate = log_firing_rate.squeeze()
        spikes = spikes.squeeze()
        
        if np.any(log_firing_rate==MAX_FIRING_RATE):
            explosion_trial += 1
            pass
        else:
            spikes_rcd[:,:,itrial] = spikes
            log_firing_rate_rcd[:,:,itrial] = log_firing_rate
            break

# %%
explosion_trial/(explosion_trial+model_list[0].ntrial)
# Out:
# 0.8700906344410876

# %%
for iprobe, probe in enumerate(probe_list):
    plt.plot(np.exp(log_firing_rate_rcd)[:,iprobe,].mean(axis=1), label=utils.PROBE_CORRESPONDING[probe])
plt.legend()
plt.title("PSTH of simulation (stationary)")
# Out:
# Text(0.5, 1.0, 'PSTH of simulation (stationary)')

# %%
model.output.shape
# Out:
# (500, 129)

# %% [markdown]
# # Hard refractory

# %% [markdown]
# There's no hard refractory period in the data. The minimum ISI can be as short as 1ms.

# %%
for model in running_model_list:
    print(model.response.max())
    print(model.log_lmbd.max())
# Out:
# 6.0
# 0.7052046860052917
# 5.0
# 0.2970742483773627
# 7.0
# 1.1085037573204026
# 4.0
# 0.5686377787095604
# 5.0
# 1.6485821459673904
# 4.0
# -0.24620008796812387

# %%
for model in stationary_model_list:
    print(model.response.max())
    print(model.log_lmbd.max())
# Out:
# 5.0
# 1.4076303981256313
# 5.0
# 0.8667822094375486
# 8.0
# 1.9709679903028752
# 5.0
# 1.2546819414879786
# 6.0
# 1.48600295659956
# 4.0
# -0.08812377769016488

# %% [markdown]
# # Non-linear history (Interaction)

# %% [markdown]
# ## Hyperparameter tuning (tau)

# %% [markdown]
# ### probeA

# %%
select_trials = V1.stationary_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeA'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

# Baseline
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

baseline_nll = model.nll

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append((model.results.params[-coupling_filter_params['num']]))
    bse_list.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list.append(model.nll)

para_list2 = []
bse_list2 = []
nll_list2 = []
for i, tau in enumerate(tau_list2):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=16, **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list2.append((model.results.params[-coupling_filter_params['num']]))
    bse_list2.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list2.append(model.nll)
    
para_list3 = []
bse_list3 = []
nll_list3 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=2, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list3.append((model.results.params[-1]))
    bse_list3.append((model.results.bse[-1]))
    nll_list3.append(model.nll)
    
para_list0 = []
bse_list0 = []
nll_list0 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=1, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list0.append((model.results.params[-1]))
    bse_list0.append((model.results.bse[-1]))
    nll_list0.append(model.nll)

# %%
tau_list = tau_list
x = np.array(tau_list)
y = np.array(para_list3)
ci = np.array(bse_list3)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.title('coef of $\Lambda^2$ in the third method')
plt.xscale('log')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b', label='only $\Lambda \cdot g_1(s)$')
plt.plot(tau_list, nll_list2, '-.', color='b', label='both $\Lambda \cdot g_1(s)$ and $\Lambda^2 \cdot g_2(s)$')
plt.plot(tau_list, nll_list0, '-', color='g', label='$\Lambda$')
plt.plot(tau_list, nll_list3, '-.', color='g', label='$\Lambda^2$')
plt.axhline(baseline_nll, color='r', label='None')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.legend(loc=1)
plt.ylim([25300, 26400])
plt.title('nll of different method')
plt.xscale('log')
plt.tight_layout()
plt.suptitle(f'{utils.PROBE_CORRESPONDING[target_probe]}')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [258], in <cell line: 24>()
#      22 plt.legend(loc=1)
#      23 plt.ylim([25300, 26400])
# ---> 24 plt.title()
#      25 plt.xscale('log')
#      26 plt.tight_layout()
#
# TypeError: title() missing 1 required positional argument: 'label'

# %% [markdown]
# ### probeB

# %%
select_trials = V1.stationary_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeB'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

# Baseline
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

baseline_nll = model.nll

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append((model.results.params[-coupling_filter_params['num']]))
    bse_list.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list.append(model.nll)

para_list2 = []
bse_list2 = []
nll_list2 = []
for i, tau in enumerate(tau_list2):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=16, **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list2.append((model.results.params[-coupling_filter_params['num']]))
    bse_list2.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list2.append(model.nll)
    
para_list3 = []
bse_list3 = []
nll_list3 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=2, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list3.append((model.results.params[-coupling_filter_params['num']]))
    bse_list3.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list3.append(model.nll)
    
para_list0 = []
bse_list0 = []
nll_list0 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=1, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list0.append((model.results.params[-1]))
    bse_list0.append((model.results.bse[-1]))
    nll_list0.append(model.nll)

# %%
tau_list = tau_list
x = np.array(tau_list)
y = np.array(para_list3)
ci = np.array(bse_list3)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.xscale('log')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b', label='only 1st order interaction')
plt.plot(tau_list, nll_list2, '-.', color='b', label='1st and 2nd order interaction')
plt.plot(tau_list, nll_list0, '-', color='g', label='$\Lambda$')
plt.plot(tau_list, nll_list3, '-.', color='g', label='$\Lambda^2$')
plt.axhline(baseline_nll, color='r', label='no interaction')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.legend(loc=1)
plt.ylim([21300, 22000-200])
plt.title(f'{utils.PROBE_CORRESPONDING[target_probe]}')
plt.xscale('log')
plt.tight_layout()

# %% [markdown]
# ### probeC

# %% [markdown]
# #### Stationary

# %%
select_trials = V1.stationary_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeC'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

# Baseline
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

baseline_nll = model.nll

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append((model.results.params[-coupling_filter_params['num']]))
    bse_list.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list.append(model.nll)

para_list2 = []
bse_list2 = []
nll_list2 = []
for i, tau in enumerate(tau_list2):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=16, **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list2.append((model.results.params[-coupling_filter_params['num']]))
    bse_list2.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list2.append(model.nll)
    
para_list3 = []
bse_list3 = []
nll_list3 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=2, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list3.append((model.results.params[-coupling_filter_params['num']]))
    bse_list3.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list3.append(model.nll)
    
para_list0 = []
bse_list0 = []
nll_list0 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=1, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list0.append((model.results.params[-1]))
    bse_list0.append((model.results.bse[-1]))
    nll_list0.append(model.nll)

# %%
tau_list = tau_list
x = np.array(tau_list)
y = np.array(para_list3)
ci = np.array(bse_list3)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.xscale('log')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b', label='only 1st order interaction')
plt.plot(tau_list2, nll_list2, '-.', color='b', label='1st and 2nd order interaction')
plt.plot(tau_list3, nll_list0, '-', color='g', label='$\Lambda$')
plt.plot(tau_list3, nll_list3, '-.', color='g', label='$\Lambda^2$')
plt.axhline(baseline_nll, color='r', label='no interaction')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.legend(loc=1)
plt.ylim([30000-100, 31800])
plt.suptitle(f'{utils.PROBE_CORRESPONDING[target_probe]}')
plt.xscale('log')
plt.tight_layout()

# %% [markdown]
# #### Running

# %%
select_trials = V1.running_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeC'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

# Baseline
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

baseline_nll = model.nll

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append((model.results.params[-coupling_filter_params['num']]))
    bse_list.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list.append(model.nll)

para_list2 = []
bse_list2 = []
nll_list2 = []
for i, tau in enumerate(tau_list2):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=16, **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list2.append((model.results.params[-coupling_filter_params['num']]))
    bse_list2.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list2.append(model.nll)
    
para_list3 = []
bse_list3 = []
nll_list3 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=2, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list3.append((model.results.params[-coupling_filter_params['num']]))
    bse_list3.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list3.append(model.nll)
    
para_list0 = []
bse_list0 = []
nll_list0 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=1, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list0.append((model.results.params[-1]))
    bse_list0.append((model.results.bse[-1]))
    nll_list0.append(model.nll)

# %%
tau_list = tau_list
x = np.array(tau_list)
y = np.array(para_list3)
ci = np.array(bse_list3)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.xscale('log')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.plot(tau_list2, nll_list2, '-.', color='b')
plt.axhline(baseline_nll, color='r')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(f'{utils.PROBE_CORRESPONDING[target_probe]}')
plt.xscale('log')
plt.tight_layout()

# %% [markdown]
# ### probeD

# %% [markdown]
# #### Stationary

# %%
select_trials = V1.stationary_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeD'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

# Baseline
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

baseline_nll = model.nll

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append((model.results.params[-coupling_filter_params['num']]))
    bse_list.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list.append(model.nll)

para_list2 = []
bse_list2 = []
nll_list2 = []
for i, tau in enumerate(tau_list2):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=16, **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list2.append((model.results.params[-coupling_filter_params['num']]))
    bse_list2.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list2.append(model.nll)
    
para_list3 = []
bse_list3 = []
nll_list3 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=2, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list3.append((model.results.params[-coupling_filter_params['num']]))
    bse_list3.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list3.append(model.nll)
    
para_list0 = []
bse_list0 = []
nll_list0 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=1, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list0.append((model.results.params[-1]))
    bse_list0.append((model.results.bse[-1]))
    nll_list0.append(model.nll)

# %%
tau_list = tau_list
x = np.array(tau_list)
y = np.array(para_list3)
ci = np.array(bse_list3)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.xscale('log')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.plot(tau_list2, nll_list2, '-.', color='b')
plt.axhline(baseline_nll, color='r')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(f'{utils.PROBE_CORRESPONDING[target_probe]}')
plt.xscale('log')
plt.tight_layout()

# %% [markdown]
# #### Running

# %%
select_trials = V1.running_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeD'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

# Baseline
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

baseline_nll = model.nll

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append((model.results.params[-coupling_filter_params['num']]))
    bse_list.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list.append(model.nll)

para_list2 = []
bse_list2 = []
nll_list2 = []
for i, tau in enumerate(tau_list2):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=16, **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list2.append((model.results.params[-coupling_filter_params['num']]))
    bse_list2.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list2.append(model.nll)
    
para_list3 = []
bse_list3 = []
nll_list3 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=2, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list3.append((model.results.params[-coupling_filter_params['num']]))
    bse_list3.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list3.append(model.nll)
    
para_list0 = []
bse_list0 = []
nll_list0 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=1, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list0.append((model.results.params[-1]))
    bse_list0.append((model.results.bse[-1]))
    nll_list0.append(model.nll)

# %%
tau_list = tau_list
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.xscale('log')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.plot(tau_list2, nll_list2, '-.', color='b')
plt.axhline(baseline_nll, color='r')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(f'{utils.PROBE_CORRESPONDING[target_probe]}')
plt.xscale('log')
plt.tight_layout()

# %% [markdown]
# ### probeE

# %%
select_trials = V1.stationary_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeE'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

# Baseline
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

baseline_nll = model.nll

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append((model.results.params[-coupling_filter_params['num']]))
    bse_list.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list.append(model.nll)

para_list2 = []
bse_list2 = []
nll_list2 = []
for i, tau in enumerate(tau_list2):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=16, **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list2.append((model.results.params[-coupling_filter_params['num']]))
    bse_list2.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list2.append(model.nll)
    
para_list3 = []
bse_list3 = []
nll_list3 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=2, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list3.append((model.results.params[-coupling_filter_params['num']]))
    bse_list3.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list3.append(model.nll)
    
para_list0 = []
bse_list0 = []
nll_list0 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=1, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list0.append((model.results.params[-1]))
    bse_list0.append((model.results.bse[-1]))
    nll_list0.append(model.nll)

# %%
tau_list = tau_list
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.xscale('log')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.plot(tau_list2, nll_list2, '-.', color='b')
plt.axhline(baseline_nll, color='r')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(f'{utils.PROBE_CORRESPONDING[target_probe]}')
plt.xscale('log')
plt.tight_layout()

# %% [markdown]
# ### probeF

# %%
select_trials = V1.stationary_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeF'
tau_list = np.logspace(np.log10(1), np.log10(200), 20)
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

# Baseline
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

baseline_nll = model.nll

para_list = []
bse_list = []
nll_list = []
for i, tau in enumerate(tau_list):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list.append((model.results.params[-coupling_filter_params['num']]))
    bse_list.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list.append(model.nll)

para_list2 = []
bse_list2 = []
nll_list2 = []
for i, tau in enumerate(tau_list2):
    num_basis_baseline = 30

    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=16, **coupling_filter_params)
    model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list2.append((model.results.params[-coupling_filter_params['num']]))
    bse_list2.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list2.append(model.nll)
    
para_list3 = []
bse_list3 = []
nll_list3 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=2, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list3.append((model.results.params[-coupling_filter_params['num']]))
    bse_list3.append((model.results.bse[-coupling_filter_params['num']]))
    nll_list3.append(model.nll)
    
para_list0 = []
bse_list0 = []
nll_list0 = []
for i, tau in enumerate(tau_list3):
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
    for j, input_probe in enumerate(probe_list):
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('refractory', target_probe, order=1, tau=tau)
#     model.add_effect('interaction', target_probe, tau=10, **coupling_filter_params)
#     model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)
    para_list0.append((model.results.params[-1]))
    bse_list0.append((model.results.bse[-1]))
    nll_list0.append(model.nll)

# %%
tau_list = tau_list
x = np.array(tau_list)
y = np.array(para_list)
ci = np.array(bse_list)

plt.subplots(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(x, y, color='b')
plt.fill_between(x, (y-2*ci), (y+2*ci), color='b', alpha=.3)
plt.xlabel(r'$\tau$')
plt.ylabel(r'estimated coefficient')
plt.xscale('log')
plt.subplot(1,2,2)
plt.plot(tau_list, nll_list, color='b')
plt.plot(tau_list2, nll_list2, '-.', color='b')
plt.axhline(baseline_nll, color='r')
plt.xlabel(r'$\tau$')
plt.ylabel(r'Negative log likelihood')
plt.title(f'{utils.PROBE_CORRESPONDING[target_probe]}')
plt.xscale('log')
plt.tight_layout()

# %%
tau_list[np.argmin(nll_list)]
# Out:
# 65.554517945304

# %% [markdown]
# ## Some random tunning

# %%
# The following hyperparameters turned out to be the best
select_trials = V1.stationary_trial_index
max_iter = 10
self_effect = False
target_probe = 'probeC'
tau = 10
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}
coupling_filter_params1 = {'peaks_max':20, 'num':2, 'nonlinear':0.3}
coupling_filter_params2 = {'peaks_max':50, 'num':5, 'nonlinear':0.3}
num_basis_baseline = 30

########## Nothing need to be changed below
probe_list = V1.selected_probes

num_basis_baseline = 30
model = GLM.PP_GLM(dataset=V1, 
                   select_trials=select_trials, 
                   membership=membership, 
                   condition_ids=condition_ids)
model.add_effect('inhomogeneous_baseline', num=num_basis_baseline)
for j, input_probe in enumerate(probe_list):
    model.add_effect('coupling', probe_list[j], **coupling_filter_params)
    model.add_effect('interaction', probe_list[j], **coupling_filter_params)
# model.add_effect('interaction', target_probe, tau=tau, **coupling_filter_params)
# model.add_effect('interaction', target_probe, tau=tau, order=2, **coupling_filter_params)
model.fit_time_warping_baseline(target_probe, verbose=False, max_iter=max_iter)

model.aic
# Out:
# 30801.11071819668

# %% [markdown]
# ## Only first order interaction

# %% [markdown]
# ### Fit

# %%
tau_list = np.array([16, 10, 10, 20, 20, 70])
tau_list2 = np.array([16, 10, 10, 40, 20, 70])
self_effect = True
max_iter = 10
num_basis_baseline = 40
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}

################ No need to change below
probe_list = V1.selected_probes
running_filter = {}
stationary_filter = {}
running_model_list = []
stationary_model_list = []

for i, target_probe in enumerate(probe_list):
    select_trials = V1.running_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.add_effect('interaction', probe_list[i], tau=tau_list[i], **coupling_filter_params)
    model.add_effect('interaction', probe_list[i], tau=tau_list2[i], order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(probe_list[i], verbose=False, max_iter=max_iter)
    running_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    running_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        running_filter[i,j] = filter_list[k]
        k += 1
    
    select_trials = V1.stationary_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.add_effect('interaction', probe_list[i], tau=tau_list[i], **coupling_filter_params)
#     model.add_effect('interaction', probe_list[i], tau=tau_list2[i], order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(probe_list[i], verbose=False, max_iter=max_iter)
    stationary_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    stationary_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        stationary_filter[i,j] = filter_list[k]
        k += 1

# %% [markdown]
# ### Diagnostic

# %%
model = stationary_model_list[2]
sns.histplot(np.exp(model.log_lmbd).flatten('F'))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
nll = 0
for model in stationary_model_list:
    nll += model.nll
print(f"Total nll is {nll} for stationary conditions. ")

nll = 0
for model in running_model_list:
    nll += model.nll
print(f"Total nll is {nll} for stationary conditions. ")
# Out:
# Total nll is 139372.94905611992 for stationary conditions.
# Total nll is 141843.9515994001 for stationary conditions.

# %%
n_bin = 100
dd = 0.05
spike_sum = np.zeros(n_bin)
num_sum = np.zeros(n_bin)
for idata, lmbd in enumerate(np.exp(model.log_lmbd).flatten('F')):
    idx = int(lmbd/dd)
    if idx<n_bin:
        spike_sum[idx] += model.output.flatten('F')[idata]
        num_sum[idx] += 1
xx = np.linspace(0, n_bin*dd, n_bin)
plt.subplots(figsize=(5,4.7))
plt.plot(xx, xx, label='model prediction',color='r')
plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)
plt.legend()
# Out:
# /tmp/ipykernel_76369/3381260263.py:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)

# %%
firing_rate_list = [0, 1, 2, 3, 4, 5]
i_area = 2
model = stationary_model_list[i_area]
for firing_rate in firing_rate_list:
    filters = model.get_filter()
    plt.plot(filters[i_area+1]+firing_rate*filters[7], label=f"lambda={firing_rate}")
plt.legend()

# %%
plt.plot(filters[7])
plt.plot(filters[i_area+1])

# %%
n_bin = 100
dd = 0.05
spike_sum = np.zeros(n_bin)
num_sum = np.zeros(n_bin)
for idata, lmbd in enumerate(np.exp(model.log_lmbd).flatten('F')):
    idx = int(lmbd/dd)
    if idx<n_bin:
        spike_sum[idx] += model.output.flatten('F')[idata]
        num_sum[idx] += 1
xx = np.linspace(0, n_bin*dd, n_bin)
plt.subplots(figsize=(5,4.7))
plt.plot(xx, xx, label='model prediction',color='r')
plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)
plt.legend()
# Out:
# /tmp/ipykernel_76369/3381260263.py:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)

# %% [markdown]
# ## Second order interaction

# %% [markdown]
# ### Fit

# %%
tau_list = np.array([16, 10, 10, 20, 20, 70])
tau_list2 = np.array([16, 10, 10, 40, 20, 70])
self_effect = True
max_iter = 10
num_basis_baseline = 40
coupling_filter_params = {'peaks_max':50, 'num':6, 'nonlinear':0.3}

################ No need to change below
probe_list = V1.selected_probes
running_filter = {}
stationary_filter = {}
running_model_list = []
stationary_model_list = []

for i, target_probe in enumerate(probe_list):
    select_trials = V1.running_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.add_effect('interaction', probe_list[i], tau=tau_list[i], **coupling_filter_params)
    model.add_effect('interaction', probe_list[i], tau=tau_list2[i], order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(probe_list[i], verbose=False, max_iter=max_iter)
    running_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    running_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        running_filter[i,j] = filter_list[k]
        k += 1
    
    select_trials = V1.stationary_trial_index
    model = GLM.PP_GLM(dataset=V1, 
                       select_trials=select_trials, 
                       membership=membership, 
                       condition_ids=condition_ids)
    model.add_effect('inhomogeneous_baseline', num=num_basis_baseline, add_constant_basis=False)
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        model.add_effect('coupling', probe_list[j], **coupling_filter_params)
#     model.add_effect('trial_coef')
#     model.add_effect('refractory', probe_list[i], tau=tau_list[i])
    model.add_effect('interaction', probe_list[i], tau=tau_list[i], **coupling_filter_params)
#     model.add_effect('interaction', probe_list[i], tau=tau_list2[i], order=2, **coupling_filter_params)
    model.fit_time_warping_baseline(probe_list[i], verbose=False, max_iter=max_iter)
    stationary_model_list.append(model)
    filter_list = model.get_filter(ci=True)
    stationary_filter[i,-1] = filter_list[0]
    k = 1
    for j, input_probe in enumerate(probe_list):
        if i==j and self_effect==False:
            continue
        stationary_filter[i,j] = filter_list[k]
        k += 1

# %% [markdown]
# ### Dignostic

# %%
model = stationary_model_list[2]
sns.histplot(np.exp(model.log_lmbd).flatten('F'))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
nll = 0
for model in stationary_model_list:
    nll += model.nll
print(f"Total nll is {nll} for stationary conditions. ")

nll = 0
for model in running_model_list:
    nll += model.nll
print(f"Total nll is {nll} for stationary conditions. ")
# Out:
# Total nll is 139388.7641082364 for stationary conditions.
# Total nll is 141928.43793657073 for stationary conditions.

# %%
n_bin = 100
dd = 0.05
spike_sum = np.zeros(n_bin)
num_sum = np.zeros(n_bin)
for idata, lmbd in enumerate(np.exp(model.log_lmbd).flatten('F')):
    idx = int(lmbd/dd)
    if idx<n_bin:
        spike_sum[idx] += model.output.flatten('F')[idata]
        num_sum[idx] += 1
xx = np.linspace(0, n_bin*dd, n_bin)
plt.subplots(figsize=(5,4.7))
plt.plot(xx, xx, label='model prediction',color='r')
plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)
plt.legend()
# Out:
# /tmp/ipykernel_76369/3381260263.py:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)

# %%
firing_rate_list = [0, 1, 2, 3, 4, 5]
i_area = 2
model = stationary_model_list[i_area]
for firing_rate in firing_rate_list:
    filters = model.get_filter()
    plt.plot(filters[i_area+1]+firing_rate*filters[7], label=f"lambda={firing_rate}")
plt.legend()

# %%
plt.plot(filters[7])
plt.plot(filters[i_area+1])

# %%
n_bin = 100
dd = 0.05
spike_sum = np.zeros(n_bin)
num_sum = np.zeros(n_bin)
for idata, lmbd in enumerate(np.exp(model.log_lmbd).flatten('F')):
    idx = int(lmbd/dd)
    if idx<n_bin:
        spike_sum[idx] += model.output.flatten('F')[idata]
        num_sum[idx] += 1
xx = np.linspace(0, n_bin*dd, n_bin)
plt.subplots(figsize=(5,4.7))
plt.plot(xx, xx, label='model prediction',color='r')
plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)
plt.legend()
# Out:
# /tmp/ipykernel_76369/3381260263.py:13: RuntimeWarning: invalid value encountered in true_divide
#   plt.bar(xx, height=spike_sum/num_sum, width=dd, label='sample mean', alpha=0.3)

# %% [markdown]
# ## Plot

# %%
# use_all are all False
name_list = ['AM', 'PM', 'V1', 'LM', 'AL', 'RL']
fontsize = 15

sns.reset_orig()
# sns.set_theme()
plt.subplots(figsize=(15,10))
for i in range(len(probe_list)):
    for j in range(-1, len(probe_list)):
        if i==j and self_effect==False:
            continue
        ax = plt.subplot(6, 7, i*7+j+1+1, frameon=True)
        filter_index = i,j
        y, ci = running_filter[filter_index]
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, np.exp(y),label='running', color='r')
            plt.fill_between(x, np.exp((y-2*ci)), np.exp((y+2*ci)), color='r', alpha=.3)
        else:
            plt.plot(x, y,label='running', color='r')
            plt.fill_between(x, y-2*ci, y+2*ci, color='r', alpha=.3)
            
        y, ci = stationary_filter[filter_index]
        x = np.arange(y.shape[0])
        if j == -1:
            plt.plot(x, np.exp(y),label='stationary', color='b')
            plt.fill_between(x, np.exp((y-2*ci)), np.exp((y+2*ci)), color='b', alpha=.3)
            plt.xticks([0, 250, 500])
            plt.xlim([0, 500])
            
        else:
            plt.plot(x, y,label='stationary', color='b')
            plt.fill_between(x, y-2*ci, y+2*ci, color='b', alpha=.3)
            plt.yticks([0])
            plt.ylim([-0.17, 0.17])
            plt.yticks(color='w')
            plt.xticks([0, 50, 100])
            plt.xlim([0, 100])
            if i==0:
                plt.text(40, 0.2, f'From: {name_list[j]}', fontsize=fontsize)
                
        if j==0:
            plt.text(-210, 0, f'To: {name_list[i]}', fontsize=fontsize)
        if i != 5:
            plt.xticks(color='w')
        plt.grid()
        
        if i==0 and j==2:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(-450, 0, f'To: AM', fontsize=fontsize)
        if i==1 and j==0:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(40, 0.61, f'From: AM', fontsize=fontsize)
        if i==0 and j==-1:
            plt.subplot(6, 7, i*7+j+1+1, frameon=True)
            plt.text(0, 0.37, f'Inhomo baseline', fontsize=fontsize)

# %% [markdown]
# ## Simulate running_model_list

# %%
MAX_FIRING_RATE = 2
# MAX_FIRING_RATE = np.log(np.array([0.70520469, 0.29707425, 1.10850376, 0.56863778, 1.64858215, -0.24620009])+0.3)
model_list = stationary_model_list
itrial = 0

import copy
import numpy.random
nneuron = len(model_list)
# Get three dimension matrix of coupling filters for better computing. 
max_histories = 1
max_histories_refractory = 1
nt = model_list[0].nt
# allowed_effect_type = ['inhomogeneous_baseline', 'coupling']
allowed_effect_type = ['inhomogeneous_baseline', 'coupling', 'trial_coef', 'interaction']
coupling_mat = np.zeros((max_histories, nneuron, nneuron))
refractory_mat = np.zeros((max_histories_refractory, nneuron, nneuron))
baseline_mat = np.zeros((nt, nneuron))
spikes = np.zeros((nt, nneuron, 1))
probe2num = {}
for iprobe, probe in enumerate(probe_list):
    probe2num[probe] = iprobe

for ineuron in range(nneuron):
    assert all(effect_type in allowed_effect_type for effect_type in model_list[ineuron].effect_type_list), \
        "Only support inhomogeneous_baseline and coupling effects now!"
    model = model_list[ineuron]
    for ieffect, effect_type in enumerate(model.effect_type_list):
        
        if effect_type in ['inhomogeneous_baseline', ]:
            baseline_mat[:, ineuron] = model.filters[ieffect]
#             baseline_mat[:, ineuron] = GLM.apply_warping_to_predictors(V1.time_line, 
#                                                                        baseline_mat[:, ineuron][:,None], 
#                                                                        model_list[0].shifts[itrial,:][None,:], 
#                                                                        model_list[0].nt).squeeze()
        elif effect_type in ['coupling']:
            nhistories = len(model.filters[ieffect])
            probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
            iprobe = probe2num[probe_name]
            if nhistories > max_histories:
                coupling_mat_old = coupling_mat
                coupling_mat = np.zeros((nhistories, nneuron, nneuron))
                coupling_mat[-max_histories:, :, :] = coupling_mat_old
                max_histories = nhistories
            
            coupling_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect])
            
        elif effect_type in ['interaction']:
            nhistories = len(model.filters[ieffect])
            probe_name = utils.PROBE_CORRESPONDING_INVERSE[model.basis_name[ieffect][-2:]]
            iprobe = probe2num[probe_name]
            if nhistories > max_histories_refractory:
                refractory_mat_old = refractory_mat
                refractory_mat = np.zeros((nhistories, nneuron, nneuron))
                refractory_mat[-max_histories_refractory:, :, :] = refractory_mat_old
                max_histories_refractory = nhistories
            refractory_mat[-nhistories:, iprobe, ineuron] = np.flip(model.filters[ieffect]) 

log_firing_rate = baseline_mat[:,:,np.newaxis]
spikes[0,:,0] = np.random.poisson(np.exp(log_firing_rate[0,:,0]))

recent_spike_sum = spikes[0, :, 0]

for t in range(1, nt):
    recent_spike_sum *= np.exp(-1000.0/V1.fps/tau_list)
    nhistories = min(t, max_histories)
    temp_log_firing_rate = (coupling_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
    refractory = (refractory_mat[-nhistories:, :, :] * spikes[(t-nhistories):(t), :, :]).sum(axis=(0, 1))
    refractory *= recent_spike_sum/tau_list
    log_firing_rate[t,:,0] += temp_log_firing_rate + refractory
#     log_firing_rate[t,:,0] = np.minimum(log_firing_rate[t,:,0], MAX_FIRING_RATE)
    spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))
    recent_spike_sum += spikes[t, :, 0]
    
log_firing_rate = log_firing_rate.squeeze()
spikes = spikes.squeeze()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [101], in <cell line: 63>()
#      69     log_firing_rate[t,:,0] += temp_log_firing_rate + refractory
#      70 #     log_firing_rate[t,:,0] = np.minimum(log_firing_rate[t,:,0], MAX_FIRING_RATE)
# ---> 71     spikes[t,:,0] = np.random.poisson(np.exp(log_firing_rate[t,:,0]))
#      72     recent_spike_sum += spikes[t, :, 0]
#      74 log_firing_rate = log_firing_rate.squeeze()
#
# File mtrand.pyx:3592, in numpy.random.mtrand.RandomState.poisson()
#
# File _common.pyx:845, in numpy.random._common.disc()
#
# File _common.pyx:642, in numpy.random._common.discrete_broadcast_d()
#
# File _common.pyx:376, in numpy.random._common.check_array_constraint()
#
# ValueError: lam value too large

# %% [markdown]
# ### Single trial plot

# %%
try:
    to_plot_end = np.where(log_firing_rate.squeeze().mean(axis=1)>10)[0][0]
    plt.plot(np.exp(log_firing_rate.squeeze()[:to_plot_end,:]))
except IndexError:
    plt.plot(np.exp(log_firing_rate.squeeze()[:,:]))
plt.legend(['AM','PM','V1','LM','AL','RL'])
plt.title("Firing rate of a single trial (running)")
# Out:
# Text(0.5, 1.0, 'Firing rate of a single trial (running)')
